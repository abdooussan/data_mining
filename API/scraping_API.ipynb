# %% [markdown]
# # in this project we will scape the data from tweeter using tweeter APIs.

# %% [markdown]
# *1-import:*

# %%
import tweepy
import pandas as pd 
import json
from datetime import datetime

# %% [markdown]
# *2-keys and token*

# %%
access_key = "CBtDoLULnUTme4ebsEH7uQTFQ" 
access_secret = "InObWEggK2pEC5lcjJ5tpmJ36vPjiO2TOWuRihRGGsxU9S1Ya1" 
consumer_key = "1611750454320398338-2JZduISGasnY8415As4HWTsobrKiie"
consumer_secret = "CfdsRIDkefdQb77NCHbvOKAn9pazHeEkGC0wrPFLqjvwq"

# %% [markdown]
# **3- Twitter authentication**

# %%
auth = tweepy.OAuthHandler(access_key, access_secret)   
auth.set_access_token(consumer_key, consumer_secret)

# %% [markdown]
# **4- Creating an API object**

# %%
api = tweepy.API(auth)

# %% [markdown]
# **5- Get tweets from tweeter**

# %%
tweets = api.user_timeline(screen_name='@elonmusk', 
                            # 200 is the maximum allowed count
                            count=200,
                            include_rts = False,
                            # Necessary to keep full_text 
                            # otherwise only the first 140 words are extracted
                            tweet_mode = 'extended'
                            )

# %% [markdown]
# **6- print tweets**

# %%
for tweet in tweets :
      print("=====================================")
      print(tweet )
# Out:
# ...
# Status(_api=<tweepy.api.API object at 0x104d09510>, _json={'created_at': 'Sat Jan 14 21:41:53 +0000 2023', 'id': 1614377287557984256, 'id_str': '1614377287557984256', 'full_text': '@teslaownersSV @Teslarati @JohnnaCrider1 Many small things. We’re starting to make use of neural nets for vehicle navigation &amp; control, not just vision.', 'truncated': False, 'display_text_range': [41, 156], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'teslaownersSV', 'name': 'Tesla Owners Silicon Valley', 'id': 1016059981907386368, 'id_str': '1016059981907386368', 'indices': [0, 14]}, {'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [15, 25]}, {'screen_name': 'JohnnaCrider1', 'name': 'Johnna Crider', 'id': 1957568797, 'id_str': '1957568797', 'indices': [26, 40]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1614376401481920513
# ...
